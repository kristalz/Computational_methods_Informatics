# %%
import pandas as pd
data = pd.read_csv('C:/Users/kryst/OneDrive/Desktop/Fall 1st/BIS 634/BIS_634_HW/incd.csv',skiprows=8) 
data
# Out:
#                                                 State     FIPS  \
# 0                                   US (SEER+NPCR)(1)      0.0
# 1                                         Kentucky(7)  21000.0
# 2                                       New Jersey(7)  34000.0
# 3                                             Iowa(7)  19000.0
# 4                                    West Virginia(6)  54000.0
# ..                                                ...      ...
# 69  6 Source: National Program of Cancer Registrie...      NaN
# 70           7 Source: SEER November 2020 submission.      NaN
# 71  8 Source: Incidence data provided by the SEER ...      NaN
# 72  Interpret Rankings provides insight into inter...      NaN
# 73  Data for United States does not include Puerto...      NaN
#
#    Met Healthy People Objective of ***?  \
# 0                                   ***
# 1                                   ***
# 2                                   ***
# 3                                   ***
# ...

# %%
# Replace all missing values 
data = pd.read_csv('C:/Users/kryst/OneDrive/Desktop/Fall 1st/BIS 634/BIS_634_HW/incd.csv',skiprows=8,na_values = ['***','N/A ',' N/A ',' N/A','*']) 
data
# Out:
#                                                 State     FIPS  \
# 0                                   US (SEER+NPCR)(1)      0.0
# 1                                         Kentucky(7)  21000.0
# 2                                       New Jersey(7)  34000.0
# 3                                             Iowa(7)  19000.0
# 4                                    West Virginia(6)  54000.0
# ..                                                ...      ...
# 69  6 Source: National Program of Cancer Registrie...      NaN
# 70           7 Source: SEER November 2020 submission.      NaN
# 71  8 Source: Incidence data provided by the SEER ...      NaN
# 72  Interpret Rankings provides insight into inter...      NaN
# 73  Data for United States does not include Puerto...      NaN
#
#     Met Healthy People Objective of ***?  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# ...

# %%
# Remove the lines that are not inside the table
# From the table, we know the last state/territory is Puerto Rico
# First, let's find the index 

data[data['State'] == 'Puerto Rico(6)'].index
# Out:
# Int64Index([52], dtype='int64')

# %%
# Then remove all the rows below that index row 
data.drop(data.tail(74-53).index,inplace=True) 
data
# Out:
#                       State     FIPS  Met Healthy People Objective of ***?  \
# 0         US (SEER+NPCR)(1)      0.0                                   NaN
# 1               Kentucky(7)  21000.0                                   NaN
# 2             New Jersey(7)  34000.0                                   NaN
# 3                   Iowa(7)  19000.0                                   NaN
# 4          West Virginia(6)  54000.0                                   NaN
# 5               New York(7)  36000.0                                   NaN
# 6              Louisiana(7)  22000.0                                   NaN
# 7           Pennsylvania(6)  42000.0                                   NaN
# 8               Delaware(6)  10000.0                                   NaN
# 9          New Hampshire(6)  33000.0                                   NaN
# 10              Arkansas(6)   5000.0                                   NaN
# ...

# %%
# Remove the reference numbers in the state column
for i in range(len(data['State'])):
    data['State'][i] = data['State'][i][0:-3]
data
# Out:
# C:\Users\kryst\AppData\Local\Temp/ipykernel_37416/3809654512.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    State     FIPS  Met Healthy People Objective of ***?  \
# 0         US (SEER+NPCR)      0.0                                   NaN
# 1               Kentucky  21000.0                                   NaN
# 2             New Jersey  34000.0                                   NaN
# 3                   Iowa  19000.0                                   NaN
# 4          West Virginia  54000.0                                   NaN
# 5               New York  36000.0                                   NaN
# 6              Louisiana  22000.0                                   NaN
# 7           Pennsylvania  42000.0                                   NaN
# ...

# %%
# Export the cleaned data frame to a csv file
data.to_csv('cancer_profiles.csv', index=False)

# %%
# Open the cleaned csv file
cancer_profiles = pd.read_csv('cancer_profiles.csv')
cancer_profiles
# Out:
#                    State     FIPS  Met Healthy People Objective of ***?  \
# 0         US (SEER+NPCR)      0.0                                   NaN
# 1               Kentucky  21000.0                                   NaN
# 2             New Jersey  34000.0                                   NaN
# 3                   Iowa  19000.0                                   NaN
# 4          West Virginia  54000.0                                   NaN
# 5               New York  36000.0                                   NaN
# 6              Louisiana  22000.0                                   NaN
# 7           Pennsylvania  42000.0                                   NaN
# 8               Delaware  10000.0                                   NaN
# 9          New Hampshire  33000.0                                   NaN
# 10              Arkansas   5000.0                                   NaN
# 11                 Maine  23000.0                                   NaN
# ...
